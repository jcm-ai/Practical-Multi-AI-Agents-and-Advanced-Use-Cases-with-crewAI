# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Task Breakdown**
#
# 1. **Project Kick-Off & Meeting**
#    - **Description**: Initial meeting to align expectations, agree on timelines, discuss project scope, and define roles.
#    - **Duration**: 1 day
#    - **Dependencies**: None
#    - **Deliverables**: Meeting notes, project scope document.
#
# 2. **Requirements Analysis**
#    - **Description**: Gather detailed requirements from stakeholders to ensure all aspects of the website are covered.
#    - **Duration**: 2 days
#    - **Dependencies**: Project Kick-Off Meeting
#    - **Deliverables**: Requirements document.
#
# ---
#
# 3. **Design Phase**
#    - **Create a Responsive Design**
#      - **Description**: Design layout to ensure compatibility across devices (desktop, tablet, mobile).
#      - **Duration**: 5 days
#      - **Dependencies**: Requirements Analysis
#      - **Deliverables**: Wireframes, mockups, responsive design prototype.
#
#    - **Implement Modern User Interface**
#      - **Description**: Develop a visually appealing system focused on a clean look.
#      - **Duration**: 4 days
#      - **Dependencies**: Responsive Design
#      - **Deliverables**: UI designs for all pages.
#
# 4. **Content Creation**
#    - **"About Us" Page**
#      - **Description**: Draft text and gather images highlighting the company's history and values.
#      - **Duration**: 2 days
#      - **Dependencies**: Requirements Analysis
#      - **Deliverables**: Final copy and images for the About Us page.
#
#    - **"Services" Page**
#      - **Description**: Create content that showcases the business's offerings with detailed descriptions.
#      - **Duration**: 3 days
#      - **Dependencies**: Requirements Analysis
#      - **Deliverables**: Final copy for Services page.
#
#    - **"Contact Us" Page**
#      - **Description**: Write content and design a form for user inquiries; integrate an interactive map.
#      - **Duration**: 3 days
#      - **Dependencies**: Requirements Analysis
#      - **Deliverables**: Final copy and interactive Contact Us layout.
#
#    - **Blog Section**
#      - **Description**: Define categories, create starter articles for the blog, and outline structure.
#      - **Duration**: 4 days
#      - **Dependencies**: Requirements Analysis
#      - **Deliverables**: Final copy for 3 initial blog posts.
#
# 5. **Development Phase**
#    - **User-Friendly Navigation System**
#      - **Description**: Develop an intuitive menu structure that enhances user experience.
#      - **Duration**: 4 days
#      - **Dependencies**: UI Implementation
#      - **Deliverables**: Functional navigation system.
#
#    - **Website Development**
#      - **Description**: Develop all pages based on designs, including responsive features and content integration.
#      - **Duration**: 10 days
#      - **Dependencies**: Content Creation, Navigation
#      - **Deliverables**: Functional website on staging server.
#
#    - **Testimonials Section**
#      - **Description**: Develop and design a section to showcase customer feedback.
#      - **Duration**: 2 days
#      - **Dependencies**: Website Development
#      - **Deliverables**: Functional testimonials section.
#
# 6. **Optimization**
#    - **SEO Implementation**
#      - **Description**: Ensure all pages are optimized for search engines, including meta tags and alt text for images.
#      - **Duration**: 3 days
#      - **Dependencies**: Website Development
#      - **Deliverables**: SEO analysis report, optimized website.
#
#    - **Loading Time Optimization**
#      - **Description**: Test and implement measures to enhance page speed.
#      - **Duration**: 2 days
#      - **Dependencies**: SEO Implementation
#      - **Deliverables**: Performance report.
#
# 7. **Final Testing & QA**
#    - **Functionality Testing**
#      - **Description**: Check all website features for proper functionality, including forms and navigation.
#      - **Duration**: 5 days
#      - **Dependencies**: Optimized Website
#      - **Deliverables**: Test report, identified issues.
#
#    - **User Acceptance Testing (UAT)**
#      - **Description**: Conduct testing with stakeholders to get their feedback.
#      - **Duration**: 3 days
#      - **Dependencies**: Functionality Testing
#      - **Deliverables**: UAT report, final adjustments.
#
# 8. **Deployment**
#    - **Go Live**
#      - **Description**: Deploy the website to the production environment.
#      - **Duration**: 1 day
#      - **Dependencies**: Successful UAT
#      - **Deliverables**: Live website.
#
# 9. **Post-Launch Support**
#    - **Monitor Performance & Fix Issues**
#      - **Description**: Monitor site performance and address any immediate issues.
#      - **Duration**: 5 days post-launch
#      - **Dependencies**: Go Live
#      - **Deliverables**: Support report, any fixes completed.
#
# ---
#
# ### Summary of Team Members and Responsibilities:
# - **John Doe (Project Manager)**: Overall project coordination, stakeholder communication, and timeline oversight.
# - **Jane Doe (Software Engineer)**: Implementation of functionality and development of the website.
# - **Bob Smith (Designer)**: Creation of UI/UX elements and overall design.
# - **Alice Johnson & Tom Brown (QA Engineers)**: Quality assurance testing and monitoring for bugs.
#
# ---
#
# ### Gantt Chart Visualization (Text Representation)
#
# ```
# | Tasks                                      | Jan 1 | Jan 2 | Jan 3 | Jan 4 | Jan 5 | Jan 6 | Jan 7 | Jan 8 | Jan 9 | Jan 10| Jan 11| Jan 12| Jan 13| Jan 14| Jan 15| Jan 16| Jan 17| Jan 18| Jan 19| Jan 20| Jan 21|
# |--------------------------------------------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|
# | Project Kick-Off & Meeting                 |  ■    |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |
# | Requirements Analysis                       |       |  ■    |  ■    |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |
# | Create Responsive Design                    |       |       |       |  ■    |  ■    |  ■    |  ■    |  ■    |       |       |       |       |       |       |       |       |       |       |       |       |       |
# | Implement Modern User Interface             |       |       |       |       |       |  ■    |  ■    |  ■    |  ■    |       |       |       |       |       |       |       |       |       |       |       |       |
# | "About Us" Page                            |       |       |       |       |       |       |       |       |  ■    |  ■    |       |       |       |       |       |       |       |       |       |       |       |
# | "Services" Page                            |       |       |       |       |       |       |       |       |       |  ■    |  ■    |  ■    |       |       |       |       |       |       |       |       |       |
# | "Contact Us" Page                          |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |       |       |       |       |       |       |       |       |
# | Blog Section                               |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |  ■    |  ■    |       |       |       |       |       |
# | User-Friendly Navigation System            |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |  ■    |  ■    |       |       |       |
# | Website Development                        |       |       |       |       |       |       |       |       |       |       |       |       |	   |  ■    |  ■    |  ■    |  ■    |  ■    |  ■    |  ■    |  ■    |
# | Testimonials Section                        |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |     ■ |    ■ |       |       |
# | SEO Implementation                          |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |  ■    |       |
# | Loading Time Optimization                   |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |       |
# | Functionality Testing                       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |  ■    |  ■    |
# | User Acceptance Testing (UAT)              |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |
# | Go Live                                    |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |
# | Monitor Performance & Fix Issues           |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |       |  ■    |  ■    |
# ```
#
# In this comprehensive plan, we’ve detailed each task, including descriptions, timelines, and dependencies, ensuring a methodical approach for the website project relevant to a small business. This meticulous breakdown will facilitate efficient execution and monitoring of the project, adhering to timelines and achieving project objectives.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# **Detailed Estimation Report for Website Project**
#
# ---
#
# **1. Project Kick-Off & Meeting**
#    - **Duration**: 1 day
#    - **Resources Required**: 1 Project Manager (John Doe)
#    - **Effort**: 8 hours
#    - **Deliverables**: Meeting notes and project scope document.
#    - **Risks**: Misalignment in stakeholder expectations could lead to project delays later.
#
# ---
#
# **2. Requirements Analysis**
#    - **Duration**: 2 days
#    - **Resources Required**: 1 Project Manager (John Doe), 1 Software Engineer (Jane Doe)
#    - **Effort**: 16 hours (PM: 8 hours, SE: 8 hours)
#    - **Deliverables**: Requirements document.
#    - **Risks**: Incomplete requirements could necessitate rework.
#
# ---
#
# **3. Design Phase**
#    - **Create a Responsive Design**
#      - **Duration**: 5 days
#      - **Resources Required**: 1 Designer (Bob Smith)
#      - **Effort**: 40 hours
#      - **Deliverables**: Wireframes, mockups, responsive design prototype.
#      - **Risks**: Need for revisions based on initial feedback, potentially extending duration.
#
#    - **Implement Modern User Interface**
#      - **Duration**: 4 days
#      - **Resources Required**: 1 Designer (Bob Smith)
#      - **Effort**: 32 hours
#      - **Deliverables**: UI designs for all pages.
#      - **Risks**: UI designs may require adjustments after the review phase.
#
# ---
#
# **4. Content Creation**
#    - **"About Us" Page**
#      - **Duration**: 2 days
#      - **Resources Required**: 1 Content Creator
#      - **Effort**: 16 hours
#      - **Deliverables**: Final copy and images.
#      - **Risks**: Delay in acquiring images could push the timeline back.
#
#    - **"Services" Page**
#      - **Duration**: 3 days
#      - **Resources Required**: 1 Content Creator
#      - **Effort**: 24 hours
#      - **Deliverables**: Final copy for Services page.
#      - **Risks**: Miscommunication on service details could lead to revision.
#
#    - **"Contact Us" Page**
#      - **Duration**: 3 days
#      - **Resources Required**: 1 Content Creator
#      - **Effort**: 24 hours
#      - **Deliverables**: Final copy and interactive layout.
#      - **Risks**: Integration bugs with the form could delay deployment.
#
#    - **Blog Section**
#      - **Duration**: 4 days
#      - **Resources Required**: 1 Content Creator
#      - **Effort**: 32 hours
#      - **Deliverables**: Final copy for 3 initial blog posts.
#      - **Risks**: Lack of timely approvals on content could extend duration.
#
# ---
#
# **5. Development Phase**
#    - **User-Friendly Navigation System**
#      - **Duration**: 4 days
#      - **Resources Required**: 1 Software Engineer (Jane Doe)
#      - **Effort**: 32 hours
#      - **Deliverables**: Functional navigation system.
#      - **Risks**: Complexity of navigation adaptations may increase work.
#
#    - **Website Development**
#      - **Duration**: 10 days
#      - **Resources Required**: 1 Software Engineer (Jane Doe)
#      - **Effort**: 80 hours
#      - **Deliverables**: Functional website on staging server.
#      - **Risks**: Unforeseen technical issues could cause delays.
#
#    - **Testimonials Section**
#      - **Duration**: 2 days
#      - **Resources Required**: 1 Software Engineer (Jane Doe)
#      - **Effort**: 16 hours
#      - **Deliverables**: Functional testimonials section.
#      - **Risks**: Difficulty sourcing testimonials can delay development.
#
# ---
#
# **6. Optimization**
#    - **SEO Implementation**
#      - **Duration**: 3 days
#      - **Resources Required**: 1 Software Engineer (Jane Doe)
#      - **Effort**: 24 hours
#      - **Deliverables**: SEO analysis report, optimized website.
#      - **Risks**: Omission of key SEO components can affect visibility.
#
#    - **Loading Time Optimization**
#      - **Duration**: 2 days
#      - **Resources Required**: 1 Software Engineer (Jane Doe)
#      - **Effort**: 16 hours
#      - **Deliverables**: Performance report.
#      - **Risks**: Inadequate testing can lead to overlooked performance hits.
#
# ---
#
# **7. Final Testing & QA**
#    - **Functionality Testing**
#      - **Duration**: 5 days
#      - **Resources Required**: 2 QA Engineers (Alice Johnson & Tom Brown)
#      - **Effort**: 80 hours (40 hours each)
#      - **Deliverables**: Test report, identified issues.
#      - **Risks**: Overlooked bugs can impact user experience.
#
#    - **User Acceptance Testing (UAT)**
#      - **Duration**: 3 days
#      - **Resources Required**: 1 Project Manager (John Doe), 2 QA Engineers (Alice Johnson & Tom Brown)
#      - **Effort**: 48 hours (PM: 8 hours, QA: 40 hours)
#      - **Deliverables**: UAT report, final adjustments.
#      - **Risks**: Stakeholder availability may hinder testing schedule.
#
# ---
#
# **8. Deployment**
#    - **Go Live**
#      - **Duration**: 1 day
#      - **Resources Required**: 1 Project Manager (John Doe), 1 Software Engineer (Jane Doe)
#      - **Effort**: 8 hours
#      - **Deliverables**: Live website.
#      - **Risks**: Any last-minute issues could affect going live.
#
# ---
#
# **9. Post-Launch Support**
#    - **Monitor Performance & Fix Issues**
#      - **Duration**: 5 days post-launch
#      - **Resources Required**: 1 Software Engineer (Jane Doe) and 2 QA Engineers (Alice Johnson & Tom Brown)
#      - **Effort**: 80 hours (SE: 20 + QA: 30 + QA: 30)
#      - **Deliverables**: Support report, fixes completed.
#      - **Risks**: Post-launch issues might necessitate immediate around-the-clock support.
#
# ---
#
# **Estimated Total Time, Resources, and Effort:**
# - **Total Duration**: 5 weeks (based on continuous working days without gaps)
# - **Total Resources**: 1 Project Manager, 1 Software Engineer, 1 Designer, 2 QA Engineers, and 1 Content Creator.
# - **Total Effort**: 328 hours
#
# **Summary of Risks and Uncertainties:**
# - **Communication Gaps**: Throughout the project phases, the efficacy of communication among team members is critical for timely task completion.
# - **Stakeholder Dependencies**: Any delay in providing necessary approvals or feedback can impact successive tasks.
# - **Resource Availability**: Unexpected absences of team members may cause delays in task execution.
# - **Technical Challenges**: Potential unforeseen technical complications during development or testing could extend effort and time.
# - **Content Approval Process**: Delays in content creation feedback sessions could push back timelines.
#
# This detailed estimation report serves as a guideline for resource allocation, timeline management, and risk assessment to ensure the successful execution of the Website project. The outlined expectations and deliverables will assist in monitoring progress and effectiveness throughout each phase of the project.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# **Resource Allocation Chart for the Website Project**
#
# | Task                                      | Assigned Team Members           | Start Date  | End Date    | Effort (Hours) |
# |-------------------------------------------|---------------------------------|-------------|-------------|-----------------|
# | 1. Project Kick-Off & Meeting             | John Doe                        | Day 1       | Day 1       | 8               |
# | 2. Requirements Analysis                  | John Doe, Jane Doe             | Day 2       | Day 3       | 16              |
# | 3. Create a Responsive Design             | Bob Smith                       | Day 4       | Day 8       | 40              |
# | 4. Implement Modern User Interface        | Bob Smith                       | Day 9       | Day 12      | 32              |
# | 5. User-Friendly Navigation System        | Jane Doe                       | Day 13      | Day 16      | 32              |
# | 6. Website Development                    | Jane Doe                       | Day 17      | Day 26      | 80              |
# | 7. Testimonials Section                   | Jane Doe                       | Day 27      | Day 28      | 16              |
# | 8. SEO Implementation                     | Jane Doe                       | Day 29      | Day 31      | 24              |
# | 9. Loading Time Optimization              | Jane Doe                       | Day 32      | Day 33      | 16              |
# | 10. Functionality Testing                 | Alice Johnson, Tom Brown       | Day 34      | Day 38      | 80              |
# | 11. User Acceptance Testing (UAT)        | John Doe, Alice Johnson, Tom Brown | Day 39      | Day 41      | 48              |
# | 12. Go Live                               | John Doe, Jane Doe             | Day 42      | Day 42      | 8               |
# | 13. Monitor Performance & Fix Issues      | Jane Doe, Alice Johnson, Tom Brown | Day 43      | Day 47      | 80              |
#
# **Summary of Rationale Behind Allocation Decisions:**
#
# 1. **Project Kick-Off & Meeting**: Assigned to John Doe, the Project Manager, who can effectively lead the project and ensure stakeholder alignment on day one.
#
# 2. **Requirements Analysis**: Involves both John Doe to manage and oversee discussions and Jane Doe to contribute technical insights, ensuring that the requirements captured are feasible and aligned with project capabilities.
#
# 3. **Responsive Design & UI Implementation**: Bob Smith, the Designer, has expertise in designing interfaces. Tasks are scheduled sequentially to allow time for feedback and adjustments after the responsive design is created.
#
# 4. **Development Tasks**: All development-related activities, including navigation systems and overall website development, have been allocated to Jane Doe. This allows for focused and efficient work by utilizing her software engineering skills. The sequential flow minimizes context switching.
#
# 5. **Testing & QA**: These tasks are divided among Alice Johnson and Tom Brown to leverage both QA engineers effectively. Their parallel work will allow for thorough coverage of functionality, leading to higher quality outputs.
#
# 6. **UAT and Deployment**: John Doe is involved again during UAT to ensure stakeholder requirements are validated, while the team’s workload is effectively managed.
#
# 7. **Post-Launch Monitoring**: Jane Doe along with both QA Engineers will address any immediate issues, which is critical for post-launch support, showing the team's readiness for potential troubleshooting.
#
# This allocation optimizes each member's skills and ensures an evenly distributed workload, maximizing project efficiency and effectiveness throughout the lifecycle of the Website project. Each task assignment has been made with considerations of the team members' current skills, availability, and existing workloads, thereby facilitating a smooth workflow and higher chances of project success.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0035
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         23642          14619               9023                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kick-Off & Meeting',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Requirements Analysis',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe', 'Jane Doe']},
#   {'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'User-Friendly Navigation System',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Website Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO Implementation',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Loading Time Optimization',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Functionality Testing',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'User Acceptance Testing (UAT)',
#    'estimated_time_hours': 48.0,
#    'required_resources': ['John Doe', 'Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Go Live',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe', 'Jane Doe']},
#   {'task_name': 'Monitor Performance & Fix Issues',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson', 'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Project Kick-Off and Planning',
#    'tasks': ['1', '2']},
#   {'milestone_name': 'Design Phase', 'tasks': ['3', '4']},
#   {'milestone_name': 'Development Phase', 'tasks': ['5', '6', '7', '8', '9']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['10', '11']},
#   {'milestone_name': 'Deployment Phase', 'tasks': ['12']},
#   {'milestone_name': 'Post-Launch Support', 'tasks': ['13']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_a70cd th {
#   font-size: 120%;
# }
# #T_a70cd  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_a70cd" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a70cd_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_a70cd_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_a70cd_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a70cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a70cd_row0_col0" class="data row0 col0" >Project Kick-Off & Meeting</td>
#       <td id="T_a70cd_row0_col1" class="data row0 col1" >8.000000</td>
#       <td id="T_a70cd_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a70cd_row1_col0" class="data row1 col0" >Requirements Analysis</td>
#       <td id="T_a70cd_row1_col1" class="data row1 col1" >16.000000</td>
#       <td id="T_a70cd_row1_col2" class="data row1 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a70cd_row2_col0" class="data row2 col0" >Create a Responsive Design</td>
#       <td id="T_a70cd_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_a70cd_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a70cd_row3_col0" class="data row3 col0" >Implement Modern User Interface</td>
#       <td id="T_a70cd_row3_col1" class="data row3 col1" >32.000000</td>
#       <td id="T_a70cd_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a70cd_row4_col0" class="data row4 col0" >User-Friendly Navigation System</td>
#       <td id="T_a70cd_row4_col1" class="data row4 col1" >32.000000</td>
#       <td id="T_a70cd_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a70cd_row5_col0" class="data row5 col0" >Website Development</td>
#       <td id="T_a70cd_row5_col1" class="data row5 col1" >80.000000</td>
#       <td id="T_a70cd_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a70cd_row6_col0" class="data row6 col0" >Testimonials Section</td>
#       <td id="T_a70cd_row6_col1" class="data row6 col1" >16.000000</td>
#       <td id="T_a70cd_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a70cd_row7_col0" class="data row7 col0" >SEO Implementation</td>
#       <td id="T_a70cd_row7_col1" class="data row7 col1" >24.000000</td>
#       <td id="T_a70cd_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a70cd_row8_col0" class="data row8 col0" >Loading Time Optimization</td>
#       <td id="T_a70cd_row8_col1" class="data row8 col1" >16.000000</td>
#       <td id="T_a70cd_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a70cd_row9_col0" class="data row9 col0" >Functionality Testing</td>
#       <td id="T_a70cd_row9_col1" class="data row9 col1" >80.000000</td>
#       <td id="T_a70cd_row9_col2" class="data row9 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a70cd_row10_col0" class="data row10 col0" >User Acceptance Testing (UAT)</td>
#       <td id="T_a70cd_row10_col1" class="data row10 col1" >48.000000</td>
#       <td id="T_a70cd_row10_col2" class="data row10 col2" >['John Doe', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a70cd_row11_col0" class="data row11 col0" >Go Live</td>
#       <td id="T_a70cd_row11_col1" class="data row11 col1" >8.000000</td>
#       <td id="T_a70cd_row11_col2" class="data row11 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a70cd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a70cd_row12_col0" class="data row12 col0" >Monitor Performance & Fix Issues</td>
#       <td id="T_a70cd_row12_col1" class="data row12 col1" >80.000000</td>
#       <td id="T_a70cd_row12_col2" class="data row12 col2" >['Jane Doe', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_fc6e5 th {
#   font-size: 120%;
# }
# #T_fc6e5  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_fc6e5" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc6e5_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_fc6e5_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc6e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc6e5_row0_col0" class="data row0 col0" >Project Kick-Off and Planning</td>
#       <td id="T_fc6e5_row0_col1" class="data row0 col1" >['1', '2']</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc6e5_row1_col0" class="data row1 col0" >Design Phase</td>
#       <td id="T_fc6e5_row1_col1" class="data row1 col1" >['3', '4']</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc6e5_row2_col0" class="data row2 col0" >Development Phase</td>
#       <td id="T_fc6e5_row2_col1" class="data row2 col1" >['5', '6', '7', '8', '9']</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc6e5_row3_col0" class="data row3 col0" >Testing Phase</td>
#       <td id="T_fc6e5_row3_col1" class="data row3 col1" >['10', '11']</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc6e5_row4_col0" class="data row4 col0" >Deployment Phase</td>
#       <td id="T_fc6e5_row4_col1" class="data row4 col1" >['12']</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc6e5_row5_col0" class="data row5 col0" >Post-Launch Support</td>
#       <td id="T_fc6e5_row5_col1" class="data row5 col1" >['13']</td>
#     </tr>
#   </tbody>
# </table>
