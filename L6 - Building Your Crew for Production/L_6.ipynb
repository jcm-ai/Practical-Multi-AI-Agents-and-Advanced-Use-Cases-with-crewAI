# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 219 packages in 1.70s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# cffi       ------------------------------     0 B/456.29 KiB
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# huggingface-hub ------------------------------     0 B/453.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# pydantic   ------------------------------     0 B/421.58 KiB
# huggingface-hub ------------------------------     0 B/453.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# langchain-core ------------------------------     0 B/403.47 KiB
# pydantic   ------------------------------     0 B/421.58 KiB
# huggingface-hub ------------------------------     0 B/453.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# prompt-toolkit ------------------------------     0 B/378.73 KiB
# langchain-core ------------------------------     0 B/403.47 KiB
# pydantic   ------------------------------     0 B/421.58 KiB
# huggingface-hub ------------------------------     0 B/453.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# openai     ------------------------------     0 B/461.21 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 30.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.73 KiB
# langchain-core ------------------------------ 30.91 KiB/403.47 KiB
# pydantic   ------------------------------ 30.92 KiB/421.58 KiB
# watchfiles ------------------------------ 30.91 KiB/441.97 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# huggingface-hub ------------------------------ 46.88 KiB/453.19 KiB
# cffi       ------------------------------ 76.45 KiB/456.29 KiB
# openai     ------------------------------ 30.89 KiB/461.21 KiB
# pytz       ------------------------------ 30.78 KiB/496.10 KiB
# mpmath     ------------------------------ 78.95 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.92 KiB/533.14 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 40.42 KiB/613.62 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 32.00 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/806.18 KiB
# langchain  ------------------------------ 14.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 78.91 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 62.79 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/378.73 KiB
# langchain-core ------------------------------ 46.91 KiB/403.47 KiB
# pydantic   ------------------------------ 94.23 KiB/421.58 KiB
# watchfiles ------------------------------ 174.81 KiB/441.97 KiB
# httptools  ------------------------------ 206.91 KiB/449.01 KiB
# huggingface-hub ------------------------------ 70.84 KiB/453.19 KiB
# cffi       ------------------------------ 188.45 KiB/456.29 KiB
# openai     ------------------------------ 62.89 KiB/461.21 KiB
# pytz       ------------------------------ 46.78 KiB/496.10 KiB
# mpmath     ------------------------------ 145.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.92 KiB/533.14 KiB
# greenlet   ------------------------------ 62.91 KiB/588.29 KiB
# chromadb   ------------------------------ 56.42 KiB/613.62 KiB
# pyvis      ------------------------------ 174.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 206.57 KiB/745.07 KiB
# regex      ------------------------------ 182.99 KiB/774.15 KiB
# ipython    ------------------------------ 63.53 KiB/806.18 KiB
# langchain  ------------------------------ 30.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 206.08 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 94.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 93.48 KiB/378.73 KiB
# langchain-core ------------------------------ 46.91 KiB/403.47 KiB
# pydantic   ------------------------------ 158.23 KiB/421.58 KiB
# watchfiles ------------------------------ 254.91 KiB/441.97 KiB
# httptools  ------------------------------ 270.91 KiB/449.01 KiB
# huggingface-hub ------------------------------ 221.83 KiB/453.19 KiB
# cffi       ------------------------------ 284.45 KiB/456.29 KiB
# openai     ------------------------------ 62.89 KiB/461.21 KiB
# pytz       ------------------------------ 46.78 KiB/496.10 KiB
# mpmath     ------------------------------ 241.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 30.92 KiB/533.14 KiB
# greenlet   ------------------------------ 271.87 KiB/588.29 KiB
# chromadb   ------------------------------ 78.92 KiB/613.62 KiB
# pyvis      ------------------------------ 270.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 260.42 KiB/745.07 KiB
# regex      ------------------------------ 253.38 KiB/774.15 KiB
# ipython    ------------------------------ 127.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 302.08 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 190.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 109.48 KiB/378.73 KiB
# langchain-core ------------------------------ 62.91 KiB/403.47 KiB
# pydantic   ------------------------------ 238.23 KiB/421.58 KiB
# watchfiles ------------------------------ 334.81 KiB/441.97 KiB
# httptools  ------------------------------ 366.91 KiB/449.01 KiB
# huggingface-hub ------------------------------ 317.83 KiB/453.19 KiB
# cffi       ------------------------------ 379.84 KiB/456.29 KiB
# openai     ------------------------------ 75.17 KiB/461.21 KiB
# pytz       ------------------------------ 62.78 KiB/496.10 KiB
# mpmath     ------------------------------ 321.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 46.81 KiB/533.14 KiB
# greenlet   ------------------------------ 367.87 KiB/588.29 KiB
# chromadb   ------------------------------ 318.09 KiB/613.62 KiB
# pyvis      ------------------------------ 350.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 334.68 KiB/745.07 KiB
# regex      ------------------------------ 327.00 KiB/774.15 KiB
# ipython    ------------------------------ 239.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 382.08 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 270.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 141.37 KiB/378.73 KiB
# langchain-core ------------------------------ 124.46 KiB/403.47 KiB
# pydantic   ------------------------------ 286.23 KiB/421.58 KiB
# watchfiles ------------------------------ 415.98 KiB/441.97 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# huggingface-hub ------------------------------ 333.83 KiB/453.19 KiB
# cffi       ------------------------------ 439.24 KiB/456.29 KiB
# openai     ------------------------------ 123.17 KiB/461.21 KiB
# pytz       ------------------------------ 107.30 KiB/496.10 KiB
# mpmath     ------------------------------ 401.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.92 KiB/533.14 KiB
# greenlet   ------------------------------ 447.87 KiB/588.29 KiB
# chromadb   ------------------------------ 382.09 KiB/613.62 KiB
# pyvis      ------------------------------ 446.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 428.78 KiB/745.07 KiB
# regex      ------------------------------ 397.38 KiB/774.15 KiB
# ipython    ------------------------------ 351.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 459.36 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 286.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 141.37 KiB/378.73 KiB
# langchain-core ------------------------------ 124.46 KiB/403.47 KiB
# pydantic   ------------------------------ 294.31 KiB/421.58 KiB
# watchfiles ------------------------------ 431.98 KiB/441.97 KiB
# huggingface-hub ------------------------------ 333.83 KiB/453.19 KiB
# cffi       ------------------------------ 455.24 KiB/456.29 KiB
# openai     ------------------------------ 123.17 KiB/461.21 KiB
# pytz       ------------------------------ 107.30 KiB/496.10 KiB
# mpmath     ------------------------------ 417.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 318.92 KiB/533.14 KiB
# greenlet   ------------------------------ 463.76 KiB/588.29 KiB
# chromadb   ------------------------------ 382.09 KiB/613.62 KiB
# pyvis      ------------------------------ 460.06 KiB/738.32 KiB
# pyyaml     ------------------------------ 444.78 KiB/745.07 KiB
# regex      ------------------------------ 413.38 KiB/774.15 KiB
# ipython    ------------------------------ 351.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 462.08 KiB/1.03 MiB
# pygments   ------------------------------ 398.04 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 286.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 157.48 KiB/378.73 KiB
# langchain-core ------------------------------ 140.46 KiB/403.47 KiB
# pydantic   ------------------------------ 310.31 KiB/421.58 KiB
# huggingface-hub ------------------------------ 349.83 KiB/453.19 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# openai     ------------------------------ 139.17 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# mpmath     ------------------------------ 417.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 446.81 KiB/533.14 KiB
# greenlet   ------------------------------ 463.87 KiB/588.29 KiB
# chromadb   ------------------------------ 398.09 KiB/613.62 KiB
# pyvis      ------------------------------ 462.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 462.68 KiB/745.07 KiB
# regex      ------------------------------ 445.38 KiB/774.15 KiB
# ipython    ------------------------------ 351.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 494.08 KiB/1.03 MiB
# pygments   ------------------------------ 414.04 KiB/1.17 MiB
# jedi       ------------------------------ 223.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# google-cloud-resource-manager ------------------------------ 286.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 157.48 KiB/378.73 KiB
# langchain-core ------------------------------ 140.46 KiB/403.47 KiB
# pydantic   ------------------------------ 310.31 KiB/421.58 KiB
# huggingface-hub ------------------------------ 349.83 KiB/453.19 KiB
# openai     ------------------------------ 139.17 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# mpmath     ------------------------------ 417.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 446.81 KiB/533.14 KiB
# greenlet   ------------------------------ 463.87 KiB/588.29 KiB
# chromadb   ------------------------------ 398.09 KiB/613.62 KiB
# pyvis      ------------------------------ 462.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 462.68 KiB/745.07 KiB
# regex      ------------------------------ 445.38 KiB/774.15 KiB
# ipython    ------------------------------ 351.53 KiB/806.18 KiB
# langchain  ------------------------------ 46.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 494.08 KiB/1.03 MiB
# pygments   ------------------------------ 414.04 KiB/1.17 MiB
# jedi       ------------------------------ 223.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 416.38 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# jiter      ------------------------------ 15.78 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 16.00 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 350.89 KiB/375.13 KiB
# prompt-toolkit ------------------------------ 189.37 KiB/378.73 KiB
# langchain-core ------------------------------ 158.91 KiB/403.47 KiB
# pydantic   ------------------------------ 366.36 KiB/421.58 KiB
# huggingface-hub ------------------------------ 365.83 KiB/453.19 KiB
# openai     ------------------------------ 155.17 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# mpmath     ------------------------------ 497.01 KiB/523.63 KiB
# crewai-tools ------------------------------ 462.81 KiB/533.14 KiB
# greenlet   ------------------------------ 511.87 KiB/588.29 KiB
# chromadb   ------------------------------ 398.09 KiB/613.62 KiB
# pyvis      ------------------------------ 526.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 521.06 KiB/745.07 KiB
# regex      ------------------------------ 509.38 KiB/774.15 KiB
# ipython    ------------------------------ 383.53 KiB/806.18 KiB
# langchain  ------------------------------ 62.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 552.30 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# jiter      ------------------------------ 64.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 78.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 221.37 KiB/378.73 KiB
# langchain-core ------------------------------ 189.43 KiB/403.47 KiB
# pydantic   ------------------------------ 414.23 KiB/421.58 KiB
# huggingface-hub ------------------------------ 397.73 KiB/453.19 KiB
# openai     ------------------------------ 188.81 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# mpmath     ------------------------------ 513.12 KiB/523.63 KiB
# crewai-tools ------------------------------ 478.92 KiB/533.14 KiB
# greenlet   ------------------------------ 543.87 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 558.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 533.15 KiB/745.07 KiB
# regex      ------------------------------ 557.38 KiB/774.15 KiB
# ipython    ------------------------------ 399.53 KiB/806.18 KiB
# langchain  ------------------------------ 62.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 590.08 KiB/1.03 MiB
# pygments   ------------------------------ 494.04 KiB/1.17 MiB
# jedi       ------------------------------ 239.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# jiter      ------------------------------ 64.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 94.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 221.37 KiB/378.73 KiB
# langchain-core ------------------------------ 189.43 KiB/403.47 KiB
# huggingface-hub ------------------------------ 397.73 KiB/453.19 KiB
# openai     ------------------------------ 188.81 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# mpmath     ------------------------------ 513.12 KiB/523.63 KiB
# crewai-tools ------------------------------ 478.92 KiB/533.14 KiB
# greenlet   ------------------------------ 543.87 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 574.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 542.68 KiB/745.07 KiB
# regex      ------------------------------ 557.38 KiB/774.15 KiB
# ipython    ------------------------------ 415.53 KiB/806.18 KiB
# langchain  ------------------------------ 62.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 590.08 KiB/1.03 MiB
# pygments   ------------------------------ 509.81 KiB/1.17 MiB
# jedi       ------------------------------ 239.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 536.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# protobuf   ------------------------------     0 B/312.18 KiB
# yarl       ------------------------------     0 B/336.08 KiB
# jiter      ------------------------------ 96.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 126.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 269.37 KiB/378.73 KiB
# langchain-core ------------------------------ 205.43 KiB/403.47 KiB
# huggingface-hub ------------------------------ 429.83 KiB/453.19 KiB
# openai     ------------------------------ 203.17 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# crewai-tools ------------------------------ 478.92 KiB/533.14 KiB
# greenlet   ------------------------------ 559.87 KiB/588.29 KiB
# chromadb   ------------------------------ 428.08 KiB/613.62 KiB
# pyvis      ------------------------------ 606.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 574.68 KiB/745.07 KiB
# regex      ------------------------------ 588.01 KiB/774.15 KiB
# ipython    ------------------------------ 447.53 KiB/806.18 KiB
# langchain  ------------------------------ 78.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 606.71 KiB/1.03 MiB
# pygments   ------------------------------ 525.81 KiB/1.17 MiB
# jedi       ------------------------------ 255.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# protobuf   ------------------------------ 3.34 KiB/312.18 KiB
# yarl       ------------------------------ 14.92 KiB/336.08 KiB
# jiter      ------------------------------ 112.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 142.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 285.48 KiB/378.73 KiB
# langchain-core ------------------------------ 254.09 KiB/403.47 KiB
# huggingface-hub ------------------------------ 429.83 KiB/453.19 KiB
# openai     ------------------------------ 219.17 KiB/461.21 KiB
# pytz       ------------------------------ 123.30 KiB/496.10 KiB
# crewai-tools ------------------------------ 478.92 KiB/533.14 KiB
# greenlet   ------------------------------ 559.87 KiB/588.29 KiB
# chromadb   ------------------------------ 444.08 KiB/613.62 KiB
# pyvis      ------------------------------ 606.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 590.68 KiB/745.07 KiB
# regex      ------------------------------ 604.01 KiB/774.15 KiB
# ipython    ------------------------------ 447.53 KiB/806.18 KiB
# langchain  ------------------------------ 78.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 622.71 KiB/1.03 MiB
# pygments   ------------------------------ 542.04 KiB/1.17 MiB
# jedi       ------------------------------ 255.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/212)
# langsmith  ------------------------------     0 B/304.50 KiB
# protobuf   ------------------------------ 51.34 KiB/312.18 KiB
# yarl       ------------------------------ 30.92 KiB/336.08 KiB
# jiter      ------------------------------ 144.00 KiB/337.45 KiB
# tzdata     ------------------------------ 32.00 KiB/338.63 KiB
# rpds-py    ------------------------------ 174.31 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 301.48 KiB/378.73 KiB
# langchain-core ------------------------------ 286.09 KiB/403.47 KiB
# openai     ------------------------------ 219.17 KiB/461.21 KiB
# pytz       ------------------------------ 139.30 KiB/496.10 KiB
# crewai-tools ------------------------------ 505.16 KiB/533.14 KiB
# greenlet   ------------------------------ 575.87 KiB/588.29 KiB
# chromadb   ------------------------------ 460.08 KiB/613.62 KiB
# pyvis      ------------------------------ 650.34 KiB/738.32 KiB
# pyyaml     ------------------------------ 622.68 KiB/745.07 KiB
# regex      ------------------------------ 622.94 KiB/774.15 KiB
# ipython    ------------------------------ 479.53 KiB/806.18 KiB
# langchain  ------------------------------ 90.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 654.08 KiB/1.03 MiB
# pygments   ------------------------------ 558.04 KiB/1.17 MiB
# jedi       ------------------------------ 255.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# qdrant-client ------------------------------ 30.91 KiB/299.45 KiB
# langsmith  ------------------------------ 16.00 KiB/304.50 KiB
# protobuf   ------------------------------ 93.65 KiB/312.18 KiB
# yarl       ------------------------------ 95.27 KiB/336.08 KiB
# jiter      ------------------------------ 208.00 KiB/337.45 KiB
# tzdata     ------------------------------ 77.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 222.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 333.48 KiB/378.73 KiB
# langchain-core ------------------------------ 318.09 KiB/403.47 KiB
# openai     ------------------------------ 235.17 KiB/461.21 KiB
# pytz       ------------------------------ 139.30 KiB/496.10 KiB
# crewai-tools ------------------------------ 521.16 KiB/533.14 KiB
# greenlet   ------------------------------ 588.29 KiB/588.29 KiB
# chromadb   ------------------------------ 472.63 KiB/613.62 KiB
# pyvis      ------------------------------ 702.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 670.68 KiB/745.07 KiB
# regex      ------------------------------ 669.38 KiB/774.15 KiB
# ipython    ------------------------------ 511.53 KiB/806.18 KiB
# langchain  ------------------------------ 106.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 717.98 KiB/1.03 MiB
# pygments   ------------------------------ 606.04 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# qdrant-client ------------------------------ 33.29 KiB/299.45 KiB
# langsmith  ------------------------------ 32.00 KiB/304.50 KiB
# protobuf   ------------------------------ 125.65 KiB/312.18 KiB
# yarl       ------------------------------ 111.16 KiB/336.08 KiB
# jiter      ------------------------------ 224.00 KiB/337.45 KiB
# tzdata     ------------------------------ 77.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 238.41 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 349.48 KiB/378.73 KiB
# langchain-core ------------------------------ 334.09 KiB/403.47 KiB
# openai     ------------------------------ 235.17 KiB/461.21 KiB
# pytz       ------------------------------ 139.30 KiB/496.10 KiB
# crewai-tools ------------------------------ 521.16 KiB/533.14 KiB
# chromadb   ------------------------------ 488.63 KiB/613.62 KiB
# pyvis      ------------------------------ 718.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 686.68 KiB/745.07 KiB
# regex      ------------------------------ 701.38 KiB/774.15 KiB
# ipython    ------------------------------ 527.53 KiB/806.18 KiB
# langchain  ------------------------------ 106.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 718.08 KiB/1.03 MiB
# pygments   ------------------------------ 638.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# qdrant-client ------------------------------ 49.19 KiB/299.45 KiB
# langsmith  ------------------------------ 48.00 KiB/304.50 KiB
# protobuf   ------------------------------ 141.65 KiB/312.18 KiB
# yarl       ------------------------------ 142.92 KiB/336.08 KiB
# jiter      ------------------------------ 256.00 KiB/337.45 KiB
# tzdata     ------------------------------ 77.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 260.30 KiB/372.36 KiB
# prompt-toolkit ------------------------------ 365.48 KiB/378.73 KiB
# langchain-core ------------------------------ 334.09 KiB/403.47 KiB
# openai     ------------------------------ 235.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 488.63 KiB/613.62 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 718.57 KiB/745.07 KiB
# regex      ------------------------------ 717.38 KiB/774.15 KiB
# ipython    ------------------------------ 578.65 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 734.08 KiB/1.03 MiB
# pygments   ------------------------------ 654.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 712.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# pypdf      ------------------------------     0 B/293.68 KiB
# qdrant-client ------------------------------ 49.19 KiB/299.45 KiB
# langsmith  ------------------------------ 48.00 KiB/304.50 KiB
# protobuf   ------------------------------ 148.61 KiB/312.18 KiB
# yarl       ------------------------------ 158.92 KiB/336.08 KiB
# jiter      ------------------------------ 260.44 KiB/337.45 KiB
# tzdata     ------------------------------ 77.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 270.41 KiB/372.36 KiB
# langchain-core ------------------------------ 350.09 KiB/403.47 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 488.63 KiB/613.62 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.57 KiB/745.07 KiB
# regex      ------------------------------ 733.38 KiB/774.15 KiB
# ipython    ------------------------------ 578.65 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 750.08 KiB/1.03 MiB
# pygments   ------------------------------ 686.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 728.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# bcrypt     ------------------------------     0 B/272.08 KiB
# pypdf      ------------------------------ 14.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 78.91 KiB/299.45 KiB
# langsmith  ------------------------------ 93.50 KiB/304.50 KiB
# protobuf   ------------------------------ 161.14 KiB/312.18 KiB
# yarl       ------------------------------ 158.92 KiB/336.08 KiB
# jiter      ------------------------------ 261.32 KiB/337.45 KiB
# tzdata     ------------------------------ 77.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 286.41 KiB/372.36 KiB
# langchain-core ------------------------------ 350.09 KiB/403.47 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 488.63 KiB/613.62 KiB
# pyyaml     ------------------------------ 734.68 KiB/745.07 KiB
# regex      ------------------------------ 749.38 KiB/774.15 KiB
# ipython    ------------------------------ 578.65 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 766.08 KiB/1.03 MiB
# pygments   ------------------------------ 686.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 744.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# cohere     ------------------------------     0 B/246.93 KiB
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 16.00 KiB/272.08 KiB
# pypdf      ------------------------------ 30.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 94.80 KiB/299.45 KiB
# langsmith  ------------------------------ 125.50 KiB/304.50 KiB
# protobuf   ------------------------------ 165.65 KiB/312.18 KiB
# yarl       ------------------------------ 190.92 KiB/336.08 KiB
# jiter      ------------------------------ 277.32 KiB/337.45 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 302.41 KiB/372.36 KiB
# langchain-core ------------------------------ 369.43 KiB/403.47 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 488.63 KiB/613.62 KiB
# regex      ------------------------------ 765.38 KiB/774.15 KiB
# ipython    ------------------------------ 623.53 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 782.08 KiB/1.03 MiB
# pygments   ------------------------------ 782.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# cohere     ------------------------------ 16.00 KiB/246.93 KiB
# frozenlist ------------------------------ 7.11 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/272.08 KiB
# pypdf      ------------------------------ 30.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 94.80 KiB/299.45 KiB
# langsmith  ------------------------------ 125.50 KiB/304.50 KiB
# protobuf   ------------------------------ 181.65 KiB/312.18 KiB
# yarl       ------------------------------ 190.92 KiB/336.08 KiB
# jiter      ------------------------------ 280.46 KiB/337.45 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 302.41 KiB/372.36 KiB
# langchain-core ------------------------------ 369.43 KiB/403.47 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 504.63 KiB/613.62 KiB
# regex      ------------------------------ 774.15 KiB/774.15 KiB
# ipython    ------------------------------ 623.53 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 798.08 KiB/1.03 MiB
# pygments   ------------------------------ 782.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# cohere     ------------------------------ 16.00 KiB/246.93 KiB
# frozenlist ------------------------------ 7.11 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/272.08 KiB
# pypdf      ------------------------------ 30.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 110.80 KiB/299.45 KiB
# langsmith  ------------------------------ 125.50 KiB/304.50 KiB
# protobuf   ------------------------------ 181.65 KiB/312.18 KiB
# yarl       ------------------------------ 190.92 KiB/336.08 KiB
# jiter      ------------------------------ 280.46 KiB/337.45 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 302.41 KiB/372.36 KiB
# langchain-core ------------------------------ 369.43 KiB/403.47 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 155.30 KiB/496.10 KiB
# chromadb   ------------------------------ 504.63 KiB/613.62 KiB
# ipython    ------------------------------ 623.53 KiB/806.18 KiB
# langchain  ------------------------------ 122.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 798.08 KiB/1.03 MiB
# pygments   ------------------------------ 798.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 776.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# google-cloud-bigquery ------------------------------     0 B/238.87 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# cohere     ------------------------------ 47.78 KiB/246.93 KiB
# frozenlist ------------------------------ 39.11 KiB/268.43 KiB
# bcrypt     ------------------------------ 60.60 KiB/272.08 KiB
# pypdf      ------------------------------ 62.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 126.80 KiB/299.45 KiB
# langsmith  ------------------------------ 173.40 KiB/304.50 KiB
# protobuf   ------------------------------ 205.65 KiB/312.18 KiB
# yarl       ------------------------------ 222.92 KiB/336.08 KiB
# jiter      ------------------------------ 312.46 KiB/337.45 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# rpds-py    ------------------------------ 334.41 KiB/372.36 KiB
# openai     ------------------------------ 251.17 KiB/461.21 KiB
# pytz       ------------------------------ 171.30 KiB/496.10 KiB
# chromadb   ------------------------------ 520.63 KiB/613.62 KiB
# ipython    ------------------------------ 639.53 KiB/806.18 KiB
# langchain  ------------------------------ 138.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 830.08 KiB/1.03 MiB
# pygments   ------------------------------ 846.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# rich       ------------------------------ 14.92 KiB/236.74 KiB
# google-cloud-bigquery ------------------------------ 28.07 KiB/238.87 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# cohere     ------------------------------ 63.78 KiB/246.93 KiB
# frozenlist ------------------------------ 64.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 96.26 KiB/272.08 KiB
# pypdf      ------------------------------ 110.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 142.91 KiB/299.45 KiB
# langsmith  ------------------------------ 205.50 KiB/304.50 KiB
# protobuf   ------------------------------ 245.31 KiB/312.18 KiB
# yarl       ------------------------------ 263.50 KiB/336.08 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# openai     ------------------------------ 267.17 KiB/461.21 KiB
# pytz       ------------------------------ 171.30 KiB/496.10 KiB
# chromadb   ------------------------------ 558.09 KiB/613.62 KiB
# ipython    ------------------------------ 655.53 KiB/806.18 KiB
# langchain  ------------------------------ 138.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 875.54 KiB/1.03 MiB
# pygments   ------------------------------ 878.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# rich       ------------------------------ 14.92 KiB/236.74 KiB
# google-cloud-bigquery ------------------------------ 28.07 KiB/238.87 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 63.78 KiB/246.93 KiB
# frozenlist ------------------------------ 80.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 96.26 KiB/272.08 KiB
# pypdf      ------------------------------ 126.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 142.91 KiB/299.45 KiB
# langsmith  ------------------------------ 221.50 KiB/304.50 KiB
# protobuf   ------------------------------ 245.31 KiB/312.18 KiB
# yarl       ------------------------------ 279.50 KiB/336.08 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# openai     ------------------------------ 267.17 KiB/461.21 KiB
# pytz       ------------------------------ 171.30 KiB/496.10 KiB
# chromadb   ------------------------------ 558.09 KiB/613.62 KiB
# ipython    ------------------------------ 655.53 KiB/806.18 KiB
# langchain  ------------------------------ 138.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 875.54 KiB/1.03 MiB
# pygments   ------------------------------ 894.04 KiB/1.17 MiB
# jedi       ------------------------------ 287.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 840.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# rich       ------------------------------ 30.92 KiB/236.74 KiB
# google-cloud-bigquery ------------------------------ 44.07 KiB/238.87 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 63.78 KiB/246.93 KiB
# frozenlist ------------------------------ 96.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 112.26 KiB/272.08 KiB
# pypdf      ------------------------------ 126.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 158.91 KiB/299.45 KiB
# langsmith  ------------------------------ 221.50 KiB/304.50 KiB
# protobuf   ------------------------------ 253.65 KiB/312.18 KiB
# yarl       ------------------------------ 295.50 KiB/336.08 KiB
# tzdata     ------------------------------ 93.92 KiB/338.63 KiB
# openai     ------------------------------ 267.17 KiB/461.21 KiB
# pytz       ------------------------------ 187.30 KiB/496.10 KiB
# chromadb   ------------------------------ 558.09 KiB/613.62 KiB
# ipython    ------------------------------ 671.53 KiB/806.18 KiB
# langchain  ------------------------------ 138.60 KiB/986.64 KiB
# tiktoken   ------------------------------ 891.54 KiB/1.03 MiB
# pygments   ------------------------------ 910.04 KiB/1.17 MiB
# jedi       ------------------------------ 287.13 KiB/1.50 MiB
# aiohttp    ------------------------------ 840.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# tomli      ------------------------------ 39.75 KiB/230.50 KiB
# crewai     ------------------------------ 48.00 KiB/234.59 KiB
# rich       ------------------------------ 62.92 KiB/236.74 KiB
# google-cloud-bigquery ------------------------------ 96.00 KiB/238.87 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 79.78 KiB/246.93 KiB
# frozenlist ------------------------------ 128.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 125.69 KiB/272.08 KiB
# pypdf      ------------------------------ 181.57 KiB/293.68 KiB
# qdrant-client ------------------------------ 222.91 KiB/299.45 KiB
# langsmith  ------------------------------ 269.50 KiB/304.50 KiB
# protobuf   ------------------------------ 301.65 KiB/312.18 KiB
# tzdata     ------------------------------ 109.92 KiB/338.63 KiB
# openai     ------------------------------ 287.17 KiB/461.21 KiB
# pytz       ------------------------------ 203.30 KiB/496.10 KiB
# chromadb   ------------------------------ 573.99 KiB/613.62 KiB
# ipython    ------------------------------ 703.42 KiB/806.18 KiB
# langchain  ------------------------------ 158.89 KiB/986.64 KiB
# tiktoken   ------------------------------ 942.08 KiB/1.03 MiB
# pygments   ------------------------------ 990.04 KiB/1.17 MiB
# jedi       ------------------------------ 287.13 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/212)
# alembic    ------------------------------     0 B/228.09 KiB
# tomli      ------------------------------ 64.00 KiB/230.50 KiB
# crewai     ------------------------------ 64.00 KiB/234.59 KiB
# rich       ------------------------------ 110.51 KiB/236.74 KiB
# google-cloud-bigquery ------------------------------ 112.00 KiB/238.87 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# cohere     ------------------------------ 96.00 KiB/246.93 KiB
# frozenlist ------------------------------ 160.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 157.69 KiB/272.08 KiB
# pypdf      ------------------------------ 206.89 KiB/293.68 KiB
# qdrant-client ------------------------------ 238.69 KiB/299.45 KiB
# langsmith  ------------------------------ 301.50 KiB/304.50 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# tzdata     ------------------------------ 109.92 KiB/338.63 KiB
# openai     ------------------------------ 287.17 KiB/461.21 KiB
# pytz       ------------------------------ 203.30 KiB/496.10 KiB
# chromadb   ------------------------------ 609.55 KiB/613.62 KiB
# ipython    ------------------------------ 719.42 KiB/806.18 KiB
# ...
# ⠹ Preparing packages... (206/212) 16.03 MiB/40.13 MiB
# pyright    ------------------------------ 2.79 MiB/5.42 MiB
# uv         ------------------------------ 14.51 MiB/15.50 MiB
# numpy      ------------------------------ 15.56 MiB/17.41 MiB
# lancedb    ------------------------------ 15.13 MiB/30.84 MiB
# pylance    ------------------------------ 14.01 MiB/36.66 MiB
# ⠹ Preparing packages... (206/212) 16.11 MiB/40.13 MiB
# pyright    ------------------------------ 2.79 MiB/5.42 MiB
# uv         ------------------------------ 14.53 MiB/15.50 MiB
# numpy      ------------------------------ 15.56 MiB/17.41 MiB
# lancedb    ------------------------------ 15.13 MiB/30.84 MiB
# pylance    ------------------------------ 14.01 MiB/36.66 MiB
# ⠹ Preparing packages... (206/212) 16.11 MiB/40.13 MiB
# pyright    ------------------------------ 2.79 MiB/5.42 MiB
# uv         ------------------------------ 14.54 MiB/15.50 MiB
# numpy      ------------------------------ 15.56 MiB/17.41 MiB
# lancedb    ------------------------------ 15.13 MiB/30.84 MiB
# pylance    ------------------------------ 14.01 MiB/36.66 MiB
# ⠹ Preparing packages... (206/212) 16.11 MiB/40.13 MiB
# pyright    ------------------------------ 2.79 MiB/5.42 MiB
# uv         ------------------------------ 14.56 MiB/15.50 MiB
# numpy      ------------------------------ 15.56 MiB/17.41 MiB
# lancedb    ------------------------------ 15.13 MiB/30.84 MiB
# pylance    ------------------------------ 14.01 MiB/36.66 MiB
# ⠹ Preparing packages... (206/212) 16.11 MiB/40.13 MiB
# pyright    ------------------------------ 2.79 MiB/5.42 MiB
# uv         ------------------------------ 15.24 MiB/15.50 MiB
# numpy      ------------------------------ 16.24 MiB/17.41 MiB
# lancedb    ------------------------------ 15.33 MiB/30.84 MiB
# pylance    ------------------------------ 14.75 MiB/36.66 MiB
# ⠸ Preparing packages... (206/212) 16.39 MiB/40.13 MiB
# pyright    ------------------------------ 2.81 MiB/5.42 MiB
# numpy      ------------------------------ 17.10 MiB/17.41 MiB
# lancedb    ------------------------------ 16.25 MiB/30.84 MiB
# pylance    ------------------------------ 14.75 MiB/36.66 MiB
# ⠸ Preparing packages... (206/212) 17.28 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# numpy      ------------------------------ 17.18 MiB/17.41 MiB
# lancedb    ------------------------------ 16.87 MiB/30.84 MiB
# pylance    ------------------------------ 14.75 MiB/36.66 MiB
# ⠸ Preparing packages... (206/212) 18.08 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# numpy      ------------------------------ 17.39 MiB/17.41 MiB
# lancedb    ------------------------------ 18.05 MiB/30.84 MiB
# pylance    ------------------------------ 17.00 MiB/36.66 MiB
# ⠸ Preparing packages... (206/212) 19.78 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# lancedb    ------------------------------ 18.31 MiB/30.84 MiB
# pylance    ------------------------------ 17.30 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 19.99 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# lancedb    ------------------------------ 19.12 MiB/30.84 MiB
# pylance    ------------------------------ 18.14 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 20.90 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# lancedb    ------------------------------ 19.12 MiB/30.84 MiB
# pylance    ------------------------------ 18.20 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 20.90 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# lancedb    ------------------------------ 19.12 MiB/30.84 MiB
# pylance    ------------------------------ 19.34 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 20.90 MiB/40.13 MiB
# pyright    ------------------------------ 2.84 MiB/5.42 MiB
# lancedb    ------------------------------ 19.12 MiB/30.84 MiB
# pylance    ------------------------------ 19.37 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 20.98 MiB/40.13 MiB
# pyright    ------------------------------ 2.98 MiB/5.42 MiB
# lancedb    ------------------------------ 19.12 MiB/30.84 MiB
# pylance    ------------------------------ 19.82 MiB/36.66 MiB
# ⠼ Preparing packages... (208/212) 21.34 MiB/40.13 MiB
# pyright    ------------------------------ 3.04 MiB/5.42 MiB
# lancedb    ------------------------------ 20.77 MiB/30.84 MiB
# pylance    ------------------------------ 20.14 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 23.52 MiB/40.13 MiB
# pyright    ------------------------------ 3.04 MiB/5.42 MiB
# lancedb    ------------------------------ 21.50 MiB/30.84 MiB
# pylance    ------------------------------ 20.73 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 23.72 MiB/40.13 MiB
# pyright    ------------------------------ 3.04 MiB/5.42 MiB
# lancedb    ------------------------------ 21.50 MiB/30.84 MiB
# pylance    ------------------------------ 20.73 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 23.75 MiB/40.13 MiB
# pyright    ------------------------------ 3.04 MiB/5.42 MiB
# lancedb    ------------------------------ 21.50 MiB/30.84 MiB
# pylance    ------------------------------ 20.73 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 23.76 MiB/40.13 MiB
# pyright    ------------------------------ 3.04 MiB/5.42 MiB
# lancedb    ------------------------------ 21.50 MiB/30.84 MiB
# pylance    ------------------------------ 20.73 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 23.78 MiB/40.13 MiB
# pyright    ------------------------------ 3.10 MiB/5.42 MiB
# lancedb    ------------------------------ 22.47 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠦ Preparing packages... (208/212) 25.91 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 22.87 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 26.77 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 22.87 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 27.34 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 22.87 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 27.36 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 22.87 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 27.37 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 22.87 MiB/30.84 MiB
# pylance    ------------------------------ 21.42 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 27.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 23.66 MiB/30.84 MiB
# pylance    ------------------------------ 23.50 MiB/36.66 MiB
# ⠧ Preparing packages... (208/212) 28.30 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 26.00 MiB/30.84 MiB
# pylance    ------------------------------ 25.73 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 28.88 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 27.16 MiB/30.84 MiB
# pylance    ------------------------------ 26.59 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 28.88 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 27.16 MiB/30.84 MiB
# pylance    ------------------------------ 26.59 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 28.98 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 27.16 MiB/30.84 MiB
# pylance    ------------------------------ 26.64 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 28.98 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 27.16 MiB/30.84 MiB
# pylance    ------------------------------ 26.66 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 28.98 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 28.02 MiB/30.84 MiB
# pylance    ------------------------------ 28.90 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 29.64 MiB/40.13 MiB
# pyright    ------------------------------ 3.29 MiB/5.42 MiB
# lancedb    ------------------------------ 30.51 MiB/30.84 MiB
# pylance    ------------------------------ 31.44 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 29.80 MiB/40.13 MiB
# pyright    ------------------------------ 3.31 MiB/5.42 MiB
# pylance    ------------------------------ 33.95 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 31.31 MiB/40.13 MiB
# pyright    ------------------------------ 3.31 MiB/5.42 MiB
# pylance    ------------------------------ 35.03 MiB/36.66 MiB
# ⠋ Preparing packages... (208/212) 31.31 MiB/40.13 MiB
# pyright    ------------------------------ 3.31 MiB/5.42 MiB
# ⠙ Preparing packages... (210/212) 32.48 MiB/40.13 MiB
# pyright    ------------------------------ 3.33 MiB/5.42 MiB
# ⠙ Preparing packages... (210/212) 32.48 MiB/40.13 MiB
# pyright    ------------------------------ 3.33 MiB/5.42 MiB
# ⠙ Preparing packages... (210/212) 32.51 MiB/40.13 MiB
# pyright    ------------------------------ 3.33 MiB/5.42 MiB
# ⠙ Preparing packages... (210/212) 32.53 MiB/40.13 MiB
# pyright    ------------------------------ 3.33 MiB/5.42 MiB
# ⠙ Preparing packages... (210/212) 32.54 MiB/40.13 MiB
# pyright    ------------------------------ 3.34 MiB/5.42 MiB
# ⠹ Preparing packages... (210/212) 34.45 MiB/40.13 MiB
# pyright    ------------------------------ 3.45 MiB/5.42 MiB
# ⠹ Preparing packages... (210/212) 36.91 MiB/40.13 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# ⠹ Preparing packages... (210/212) 38.71 MiB/40.13 MiB
# pyright    ------------------------------ 4.08 MiB/5.42 MiB
# ⠹ Preparing packages... (210/212) 40.00 MiB/40.13 MiB
# ⠹ Preparing packages... (210/212) 4.16 MiB/5.42 MiB
# Prepared 212 packages in 7.62s
# Installed 212 packages in 250ms
#  + aiohappyeyeballs==2.4.6
#  + aiohttp==3.11.12
#  + aiosignal==1.3.2
#  + alembic==1.14.1
#  + annotated-types==0.7.0
#  + anyio==4.8.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.1.0
#  + auth0-python==4.8.0
#  + backoff==2.2.1
#  + bcrypt==4.2.1
#  + beautifulsoup4==4.13.3
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.1
#  + certifi==2025.1.31
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.13.12
#  + coloredlogs==15.0.1
#  + crewai==0.102.0
#  + crewai-tools==0.36.0
#  + cryptography==44.0.1
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.126
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.8
#  + fastavro==1.10.0
#  + filelock==3.17.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.5.0
#  + fsspec==2025.2.0
#  + google-api-core==2.24.1
#  + google-auth==2.38.0
#  + google-cloud-aiplatform==1.80.0
#  + google-cloud-bigquery==3.29.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.14.0
#  + google-cloud-storage==2.19.0
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.67.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.14.0
#  + grpcio==1.70.0
#  + grpcio-status==1.70.0
#  + grpcio-tools==1.70.0
#  + h11==0.14.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.28.1
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.5.2
#  + instructor==1.7.2
#  + ipython==8.32.0
#  + jedi==0.19.2
#  + jinja2==3.1.5
#  + jiter==0.8.2
#  + json-repair==0.37.0
#  + json5==0.10.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==32.0.0
#  + lancedb==0.19.0
#  + langchain==0.3.18
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.17
#  + langchain-core==0.3.35
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.6
#  + langsmith==0.1.147
#  + litellm==1.60.2
#  + mako==1.3.9
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.49
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.63.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.30.0
#  + opentelemetry-exporter-otlp-proto-common==1.30.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.30.0
#  + opentelemetry-exporter-otlp-proto-http==1.30.0
#  + opentelemetry-instrumentation==0.51b0
#  + opentelemetry-instrumentation-asgi==0.51b0
#  + opentelemetry-instrumentation-fastapi==0.51b0
#  + opentelemetry-proto==1.30.0
#  + opentelemetry-sdk==1.30.0
#  + opentelemetry-semantic-conventions==0.51b0
#  + opentelemetry-util-http==0.51b0
#  + orjson==3.10.15
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.5
#  + pexpect==4.9.0
#  + pillow==11.1.0
#  + portalocker==2.10.1
#  + posthog==3.13.0
#  + prompt-toolkit==3.0.50
#  + propcache==0.2.1
#  + proto-plus==1.26.0
#  + protobuf==5.29.3
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==19.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.6
#  + pydantic-core==2.27.2
#  + pydantic-settings==2.7.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pylance==0.23.0
#  + pypdf==5.3.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.394
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.13.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.22.3
#  + rsa==4.9
#  + schema==0.7.7
#  + setuptools==75.8.0
#  + shapely==2.0.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.6
#  + sqlalchemy==2.0.38
#  + stack-data==0.6.3
#  + starlette==0.45.3
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.1
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2025.1
#  + urllib3==2.3.0
#  + uv==0.6.0
#  + uvicorn==0.34.0
#  + uvloop==0.21.0
#  + watchfiles==1.0.4
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0
#  + wrapt==1.17.2
#  + yarl==1.18.3
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Advancements in Multimodal Models**: In 2024, there has been significant progress in multimodal AI LLMs that can process and generate not just text but also images, audio, and video content. Models like OpenAI’s CLIP and Meta’s Mistral are leading this space, allowing for richer interactions and integrations across different media types.
#
# 2. **Improved Efficiency and Scaling**: Researchers have developed more efficient training techniques, such as sparsity and model distillation, which allow LLMs to achieve better performance with fewer resources. Techniques like low-rank adaptation (LoRA) and quantization are becoming pivotal in reducing the computational overhead while maintaining output quality.
#
# 3. **Increased Focus on Ethical AI**: Following scrutiny over prior AI models, 2024 has seen a stronger emphasis on ethical AI practices, including bias mitigation, transparency in AI processes, and user consent regarding data used for training. Regulations regarding the deployment of AI technologies are evolving to ensure better adherence to ethical standards.
#
# 4. **Customized LLMs for Niche Applications**: There is a growing trend of fine-tuning large models for specialized industries, such as healthcare, legal, and education. Companies are actively working to adapt general-purpose LLMs to cater to specific terminologies and workflows, enhancing their usability in unique contexts.
#
# 5. **Conversational AI Enhancements**: Updates in conversational AI capabilities within LLMs have significantly improved their ability to engage in context-aware dialogue. With advancements in memory augments and context-length management, LLMs demonstrate a more human-like interaction experience.
#
# 6. **Integration with Collaborative Tools**: AI LLMs are increasingly integrated into collaborative work platforms and productivity tools, streamlining workflows for businesses. Features like real-time transcription and context-aware suggestions are enhancing team collaboration and communication.
#
# 7. **Open Source Models**: The open-source model landscape continues to flourish, with initiatives like EleutherAI and Hugging Face making advanced LLM frameworks publicly accessible. This shift is encouraging innovation and experimentation, allowing smaller organizations to leverage cutting-edge capabilities without extensive investment.
#
# 8. **Data Privacy Innovations**: New techniques in federated learning and differential privacy are being incorporated into LLM training, allowing models to learn from user interactions without compromising personal data integrity. This approach is key to addressing data privacy concerns.
#
# 9. **AI-Driven Content Creation**: The creative industry is witnessing revolution due to LLMs. In 2024, they are widely being used for generating music, writing screenplays, and creating artworks, with companies leveraging AI for prototyping and experimentation in creative processes.
#
# 10. **Human-AI Collaboration Tools**: LLMs are increasingly being designed with collaborative capabilities, where human oversight is integrated into the decision-making processes. Incorporating user feedback directly into AI learning cycles helps in creating more reliable outputs while ensuring humans remain in the loop.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Detailed Report on Advancements in AI LLMs (2024)
#
# ## 1. Advancements in Multimodal Models
# In 2024, artificial intelligence has achieved remarkable progress in multimodal AI large language models (LLMs) capable of processing and generating diverse content types, including text, images, audio, and video. Leading models such as OpenAI’s CLIP and Meta’s Mistral emphasize richer interactions by seamlessly blending these modalities. This advancement allows for unprecedented applications across industries: for instance, in marketing, AI can generate video advertisements based on textual descriptions, while in education, it can create interactive learning materials that incorporate visual and audio elements. The incorporation of multimodal capabilities enriches user experiences, reinforces engagement, and enhances the ability of AI systems to understand and interpret the complexities of human communication.
#
# ## 2. Improved Efficiency and Scaling
# Significant strides have been made in improving the efficiency of LLMs, enabling researchers and developers to achieve better performance metrics with fewer resources. Techniques such as sparsity, model distillation, low-rank adaptation (LoRA), and quantization are revolutionizing the landscape of AI training. These methodologies allow for dramatic reductions in computational overhead while ensuring the quality of outputs remains uncompromised. As a result, the deployment of LLMs has become more feasible for smaller organizations and applications that do not have access to vast computational resources. Consequently, there is an emerging trend toward scaling LLM capabilities to a wider audience, leading to broader adoption across various sectors.
#
# ## 3. Increased Focus on Ethical AI
# The AI landscape in 2024 is witnessing an intensified focus on ethical practices, particularly in light of past controversies surrounding bias and misuse. This year, organizations are prioritizing the development of frameworks for bias mitigation, enhancing transparency throughout AI processes, and securing user consent for data utilized in training. Regulatory bodies are also evolving guidelines for the ethical deployment of AI technologies, fostering a culture of responsibility within the industry. Companies are now compelled to conduct regular audits of their AI systems, ensuring adherence to ethical standards, which helps build public trust and promotes a responsible approach to innovation.
#
# ## 4. Customized LLMs for Niche Applications
# As large language models become more prevalent, there is a growing trend to customize these models for niche applications across specialized industries such as healthcare, legal, and education. Organizations are actively fine-tuning general-purpose LLMs to better understand and serve specific terminologies and workflows. For instance, in healthcare, models can be tailored to comprehend medical jargon and clinical contexts, thereby improving diagnostic accuracy or patient communication. This specialization enhances the usability and effectiveness of AI solutions, ensuring they meet the unique demands of various sectors and ultimately resulting in improved service delivery.
#
# ## 5. Conversational AI Enhancements
# In 2024, conversational AI capabilities have been significantly upgraded to establish more contextually aware and human-like interactions. Advances in memory augmentation techniques and context-length management have empowered LLMs to engage users in more coherent and relevant dialogues. These enhancements allow models to maintain context over longer conversations, adapting responses based on prior user inputs. As a result, LLMs are being better equipped for applications in customer service, virtual assistants, and therapy bots, where meaningful and evolving exchanges are crucial for user satisfaction and support.
#
# ## 6. Integration with Collaborative Tools
# The integration of AI LLMs into collaborative tools and productivity platforms is growing, streamlining workflows for organizations. Features such as real-time transcription and context-aware suggestions are enhancing team communication and collaboration efficiency. By embedding LLM capabilities into tools like project management software and messaging applications, teams can leverage AI to simplify task prioritization, extract insights from discussions, and even draft documents collaboratively. This integration not only maximizes productivity but also fosters a culture of innovation and cooperation within workplaces.
#
# ## 7. Open Source Models
# The open-source landscape for AI LLMs continues to expand, with initiatives led by organizations like EleutherAI and Hugging Face making powerful LLM frameworks openly accessible. This shift is democratizing access to cutting-edge AI technologies, enabling smaller organizations and independent researchers to innovate and experiment without the burden of extensive financial investment. By fostering a collaborative environment, the open-source movement is accelerating the pace of AI advancements, allowing for diverse contributions and allowing niche applications and solutions to be developed rapidly.
#
# ## 8. Data Privacy Innovations
# In response to growing concerns regarding data privacy and user security, 2024 has seen the introduction of novel techniques such as federated learning and differential privacy into the training processes of LLMs. These methods enable AI systems to learn from user interactions while safeguarding individual data integrity. For instance, federated learning allows models to be trained on decentralized data sources, meaning user data does not need to leave their devices, thus preserving privacy. This approach is critical for compliance with regulatory standards and helps build user confidence in AI technologies, addressing long-standing privacy concerns.
# ## 9. AI-Driven Content Creation
# The creative industry is undergoing a transformation due to the application of AI LLMs in content generation. In 2024, these models are frequently utilized for tasks such as composing music, crafting screenplays, and generating artwork. Organizations and individuals are leveraging AI to propel prototyping and experimentation within creative processes, thereby enhancing productivity and inspiring originality. Moreover, AI-generated content is beginning to play a significant role in marketing campaigns and media production, challenging traditional methodologies while fostering collaborative processes between human creators and AI tools.
#
# ## 10. Human-AI Collaboration Tools
# The design of LLMs has increasingly focused on enhancing human-AI collaboration, particularly in decision-making contexts. 2024 has seen the development of systems whereby human oversight is embedded within AI processes, allowing real-time user feedback to shape and refine AI outputs. This integration ensures that while AI learns and adapts, human intervention remains a critical component, enhancing the reliability and trustworthiness of AI-generated results. By promoting a collaborative approach, organizations can ensure that their AI systems augment human capabilities rather than replace them, ultimately improving overall productivity and effectiveness.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
